# %%
import pandas as pd

# %%
print(pd.df)
# Out:
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# <ipython-input-3-d05be15fa9f4> in <module>
# ----> 1 print(pd.df)
#
# /usr/local/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'df'

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
